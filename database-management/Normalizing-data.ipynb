# %% [markdown]
# ## Introduction to Data Normalization

# %% [markdown]
# https://www.youtube.com/watch?v=j9fnpqtslMg

# %% [markdown]
# ![image.png](attachment:bb4416c3-a6af-4b27-a0bc-64de0714286b.png)

# %% [markdown]
# ## Pitfalls of Denormalized Data

# %% [markdown]
# https://www.youtube.com/watch?v=YHLEOoXLwoU

# %% [markdown]
# ![image.png](attachment:95d2dcea-c1e6-4da6-beae-15eb92a13d4d.png)

# %% [markdown]
# ## First Normal Form

# %% [markdown]
# https://www.youtube.com/watch?v=eewb9g_YHtA

# %% [markdown]
# ![image.png](attachment:8c9ee657-9f1c-4220-900a-85d6fc228de3.png)

# %% [markdown]
# https://www.youtube.com/watch?v=TfhBkwI3ovs

# %% [markdown]
# To keep the same data type in a given column of a table, go through all the existing rows of data, and make sure they're all consistent: either all numbers, or all text, dates, etc.

# %% [markdown]
# https://www.youtube.com/watch?v=rUdtUNF5Bd8

# %% [markdown]
# ![image.png](attachment:10755343-2afa-4c92-88d9-3e153880536d.png)

# %% [markdown]
# https://www.youtube.com/watch?v=u0fz2d-_hVs

# %% [markdown]
# Removing repeating columns is done in a similar fashion to when a single cell contains multiple, comma-separated values: keep a single one of the repeating columns and duplicate rows for each value in those columns.

# %% [markdown]
# https://www.youtube.com/watch?v=zzG8_hBmLhA

# %% [markdown]
# - Candidate key: a set of one or more columns that can uniquely identify a row in a table
# -
# Primary key: the key we choose from the candidate keys to uniquely represent a row in a table.

# %% [markdown]
# ![image.png](attachment:a52cff20-f30a-4162-b594-9f6d0b1cd57f.png)

# %% [markdown]
# ## First Normal Form Exercise Solution

# %% [markdown]
# https://www.youtube.com/watch?v=ksPMxXYeCTc

# %% [markdown]
# ![image.png](attachment:5be4eb5f-d2bd-49cb-8132-4444a5bf0d14.png)

# %% [markdown]
# https://www.youtube.com/watch?v=Z609MvUGV94

# %% [markdown]
# ![image.png](attachment:bf1abe75-013e-44aa-8701-0fabcc61c808.png)

# %% [markdown]
# ## Second Normal Form

# %% [markdown]
# https://www.youtube.com/watch?v=eA5MeACF6tE

# %% [markdown]
# ![image.png](attachment:2ffd4bab-8611-45ce-85df-0c5ca605412d.png)

# %% [markdown]
# https://www.youtube.com/watch?v=F9jpKcF6YEE

# %% [markdown]
# ![image.png](attachment:87e5e3f0-0d3c-41fb-bd74-ac627ca500a2.png)

# %% [markdown]
# ![image.png](attachment:47fe2fc2-1a8b-49b4-b1d1-e923ce232d20.png)

# %% [markdown]
# ![image.png](attachment:b9f6491e-4c62-4de8-b7a7-9a964fb5d8ce.png)

# %% [markdown]
# ## Second Normal Form Exercise Solution

# %% [markdown]
# https://www.youtube.com/watch?v=Y2mc_P0O9zA

# %% [markdown]
# To begin, I needed to get everything in First Normal Form, which in this case was noticing that multiple data types were used in expense_amount, and multiple values were present in some rows of the categories column. By using just numeric values for expenses, and appropriately separating the categories by rows, we’ve met the first two goals of First Normal Form. The third goal is a little more complex, so let’s look at that next.

# %% [markdown]
# https://www.youtube.com/watch?v=Z1X-bMzF7As

# %% [markdown]
# Oddly enough, none of the original rows were able to be uniquely identified, even with a primary key of all the columns combined. In this case, I added an additional id column, and combined it with the category, to uniquely identify each row. Now, we’ve achieved the first step of Second Normal Form - getting to First Normal Form.

# %% [markdown]
# https://www.youtube.com/watch?v=U3tyjs9cz_g

# %% [markdown]
# To get rid of the partial dependencies, I split out the category into another table that matches it up only to the expense id, since all other columns in a given row depend on the expense id. This gets us to Second Normal Form, although you might still think these tables look a little weird - let’s look into this.

# %% [markdown]
# https://www.youtube.com/watch?v=yhb8Ml2YIpM

# %% [markdown]
# ![image.png](attachment:731e771c-1898-4748-a759-5d8e4d78a65a.png)

# %% [markdown]
# ![image.png](attachment:0bb15ee9-2dee-436f-aa75-07535b3d51a7.png)

# %% [markdown]
# My solution tables after converting to Second Normal Form.

# %% [markdown]
# ## Third Normal Form

# %% [markdown]
# https://www.youtube.com/watch?v=pgnl7RfpUSg

# %% [markdown]
# ![image.png](attachment:36dedad6-ffa6-40d0-8a24-86dae302999f.png)

# %% [markdown]
# https://www.youtube.com/watch?v=Arq6y2040jw

# %% [markdown]
# ![image.png](attachment:cbbe94c8-8b67-4b80-85d5-a046da842604.png)

# %% [markdown]
# ![image.png](attachment:9c989f7c-5862-4522-abf8-6a524157fafe.png)

# %% [markdown]
# ## Solution: Third Normal Form Exercise

# %% [markdown]
# https://www.youtube.com/watch?v=AiTeXuSfq74

# %% [markdown]
# To start, I added a row (or multiple rows, if there was more data) to make sure only one column contained phone numbers. I also decided artist and agent_phone would have to be the primary key, even though that’s clearly an awkward situation - for now. This gets the table into First Normal Form, so let’s look at Second Normal Form next.

# %% [markdown]
# https://www.youtube.com/watch?v=ABj78jY8Cq4

# %% [markdown]
# Sometimes, following a recipe to the letter could lead to more confusion, and a more pragmatic approach is needed. Let's look at it.

# %% [markdown]
# https://www.youtube.com/watch?v=j4AGDBw3gNg

# %% [markdown]
# ![image.png](attachment:a6c38c0f-0748-420f-a434-2f65404ce3d1.png)

# %% [markdown]
# https://www.youtube.com/watch?v=TUomnRHwWxA

# %% [markdown]
# You can find my final approach to Third Normal Form below.

# %% [markdown]
# ![image.png](attachment:c4eabb68-ed6e-4b42-8a78-44a2e78cca15.png)

# %% [markdown]
# My solution tables after converting to Third Normal Form.

# %% [markdown]
# ## Valid Repetitions

# %% [markdown]
# https://www.youtube.com/watch?v=TWJNfbMrBik

# %% [markdown]
# ![image.png](attachment:389ed79a-ae87-4bd3-8469-a67856d95c7c.png)

# %% [markdown]
# ## Lesson Conclusion

# %% [markdown]
# https://www.youtube.com/watch?v=_wMezgQu0Zs

# %% [markdown]
# ![image.png](attachment:40b2f823-f020-4991-a818-6f284f88fc44.png)

# %% [markdown]
# ![image.png](attachment:76a7c68f-8313-4f0b-a47d-4d5310ca0f68.png)
