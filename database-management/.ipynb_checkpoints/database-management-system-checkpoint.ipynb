# %% [markdown]
# # Management of Relational and Non-relational Databases

# %% [markdown]
# ## Meet Your Instructor

# %% [markdown]
# https://www.youtube.com/watch?v=nvXhjvBWOEg

# %% [markdown]
# ## Prerequisites

# %% [markdown]
# https://www.youtube.com/watch?v=1EkReGa6hTI

# %% [markdown]
# ![image.png](attachment:55131f27-9d38-449b-a958-37e37df35a06.png)

# %% [markdown]
# ## Introduction to SQL vs. NoSQL

# %% [markdown]
# https://www.youtube.com/watch?v=tEsuKyqVpFw

# %% [markdown]
# ![image.png](attachment:c2e342bf-5223-4e4e-bda7-f7df2e33a7c0.png)

# %% [markdown]
# ## The Importance of Trade-offs

# %% [markdown]
# https://www.youtube.com/watch?v=bcwJw08xl8I

# %% [markdown]
# ![image.png](attachment:b96913ac-c706-4693-b5f5-5dcbe8c9a118.png)

# %% [markdown]
# ## History of "SQL vs NoSQL"

# %% [markdown]
# https://www.youtube.com/watch?v=mO9annSCceY

# %% [markdown]
# ![image.png](attachment:d4e3192f-438b-4616-b894-550d2c1852bd.png)

# %% [markdown]
# ## Course Outline

# %% [markdown]
# https://www.youtube.com/watch?v=Oh7y4fN0bCM

# %% [markdown]
# ![image.png](attachment:1c7815c8-168c-4bf8-93be-bced43624516.png)

# %% [markdown]
# ## Tools, Environment & Dependencies

# %% [markdown]
# https://www.youtube.com/watch?v=fVpZC8XY7qs

# %% [markdown]
# ![image.png](attachment:1cfc8f3b-1779-47e0-a6d8-f740f1f05b15.png)

# %% [markdown]
# ## Project: Udiddit, A Social News Aggregator

# %% [markdown]
# https://www.youtube.com/watch?v=IKeF3l9K4qQ

# %% [markdown]
# ![image.png](attachment:ffd54f7c-4f12-4ef3-bbff-09f4e09094cd.png)

# %% [markdown]
# ## Good Luck!

# %% [markdown]
# https://www.youtube.com/watch?v=v-m5dq-vsRI
