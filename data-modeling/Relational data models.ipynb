# %% [markdown]
# ## Lesson Overview

# %% [markdown]
# https://www.youtube.com/watch?v=S1G7BurtYJ0

# %% [markdown]
# ![image.png](attachment:f874089e-1ce1-49ef-a43d-7bc4462a903a.png)

# %% [markdown]
# ## Databases

# %% [markdown]
# https://www.youtube.com/watch?v=EvjmD7mTqQM

# %% [markdown]
# ![image.png](attachment:63737c36-36d8-48a6-9b62-c16334fcb36b.png)

# %% [markdown]
# ## Importance of Relational Databases

# %% [markdown]
# https://www.youtube.com/watch?v=QgBHz0bL1Sw

# %% [markdown]
# ![image.png](attachment:948460ab-c67f-4a01-a5b2-ce5b9f94a0a3.png)

# %% [markdown]
# ## OLAP vs OLTP

# %% [markdown]
# https://www.youtube.com/watch?v=ocoyWgYllFE

# %% [markdown]
# ![image.png](attachment:90fa5b48-1142-46b9-8015-8ca7881f4945.png)

# %% [markdown]
# OLTP (On-line Transaction Processing) is involved in the operation of a particular system. OLTP is characterized by a large number of short on-line transactions (INSERT, UPDATE, DELETE). The main emphasis for OLTP systems is put on very fast query processing, maintaining data integrity in multi-access environments and an effectiveness measured by number of transactions per second. In OLTP database there is detailed and current data, and schema used to store transactional databases is the entity model (usually 3NF). It involves Queries accessing individual record like Update your Email in Company database.
#
# OLAP (On-line Analytical Processing) deals with Historical Data or Archival Data. OLAP is characterized by relatively low volume of transactions. Queries are often very complex and involve aggregations. For OLAP systems a response time is an effectiveness measure. OLAP applications are widely used by Data Mining techniques. In OLAP database there is aggregated, historical data, stored in multi-dimensional schemas (usually star schema). Sometime query need to access large amount of data in Management records like what was the profit of your company in last year.

# %% [markdown]
# ![image.png](attachment:58cf4eb0-f2eb-4e57-bb04-e4658b3b3f59.png)

# %% [markdown]
# ## Structuring the Database: Normalization

# %% [markdown]
# https://www.youtube.com/watch?v=92dREpe9SLg

# %% [markdown]
# ![image.png](attachment:8563f0c2-fc8a-4e32-8aee-caa162287604.png)

# %% [markdown]
# ## Objectives of Normal Form

# %% [markdown]
# https://www.youtube.com/watch?v=B_JtLJbhszM

# %% [markdown]
# ![image.png](attachment:c7b22be2-ae53-4f43-827b-f6c923d8f942.png)

# %% [markdown]
# ## Normal Forms

# %% [markdown]
# https://www.youtube.com/watch?v=ZUnI99efjJQ

# %% [markdown]
# ![image.png](attachment:b88e5dd3-c48a-4bca-bbc5-75569f1a93c0.png)

# %% [markdown]
# ## Demo 1: Creating Normalized Tables

# %% [markdown]
# https://www.youtube.com/watch?v=zdonkmTttaI

# %% [markdown]
# ## Denormalization

# %% [markdown]
# https://www.youtube.com/watch?v=jJezt6YGweA

# %% [markdown]
# ![image.png](attachment:83c79c39-e687-4a9d-b627-6c2b53fbd640.png)

# %% [markdown]
# ## Demo 2: Creating Denormalized Tables

# %% [markdown]
# https://www.youtube.com/watch?v=Wm11Mq8ez-A

# %% [markdown]
# ## Denormalization Vs. Normalization

# %% [markdown]
# ![image.png](attachment:42a56c28-578c-4a06-9ae7-c23a777f6b16.png)

# %% [markdown]
# ## Fact and Dimension Tables

# %% [markdown]
# https://www.youtube.com/watch?v=3ala0SDBCyY

# %% [markdown]
# https://en.wikipedia.org/wiki/Dimension_(data_warehouse)

# %% [markdown]
# https://en.wikipedia.org/wiki/Fact_table

# %% [markdown]
# ![image.png](attachment:446ae7b1-65e9-4ff9-9b39-948b85747cb7.png)

# %% [markdown]
# ![image.png](attachment:8bcedfd4-ab07-422b-840b-3a6028ac97f6.png)

# %% [markdown]
# ![image.png](attachment:49debccb-ea01-4c61-9d47-df836be2281d.png)

# %% [markdown]
# https://en.wikipedia.org/wiki/Entity%E2%80%93relationship_model

# %% [markdown]
# ## Star Schemas

# %% [markdown]
# https://www.youtube.com/watch?v=i_0hq6KsjMo

# %% [markdown]
# ![image.png](attachment:f7798e6f-84de-4311-bc59-193961263b78.png)

# %% [markdown]
# https://en.wikipedia.org/wiki/Star_schema

# %% [markdown]
# https://en.wikipedia.org/wiki/Star_schema

# %% [markdown]
# ## Benefits of Star Schemas

# %% [markdown]
# https://www.youtube.com/watch?v=sfsnFmE74yY

# %% [markdown]
# ![image.png](attachment:4eab54c9-57cc-4807-9df0-9e5aab21e209.png)

# %% [markdown]
# ![image.png](attachment:eb5b7c7f-c023-49a0-afd6-fe58a6a7f179.png)

# %% [markdown]
# Music Store Database with Star Schema

# %% [markdown]
# ## Snowflake Schemas

# %% [markdown]
# https://www.youtube.com/watch?v=UAceZsZSyUs

# %% [markdown]
# ![image.png](attachment:b6f54a72-4c56-4f7e-bf0e-18677a4ad4ce.png)

# %% [markdown]
# https://en.wikipedia.org/wiki/Snowflake_schema

# %% [markdown]
# https://medium.com/@BluePi_In/deep-diving-in-the-world-of-data-warehousing-78c0d52f49a

# %% [markdown]
# ## Demo 3: Creating Fact and Dimension Tables

# %% [markdown]
# https://www.youtube.com/watch?v=GVRAWaESxfk
