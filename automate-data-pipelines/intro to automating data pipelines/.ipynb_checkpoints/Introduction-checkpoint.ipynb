# %% [markdown]
# ## Introduction

# %% [markdown]
# https://www.youtube.com/watch?v=nNUI1JfEYUI

# %% [markdown]
# ![image.png](attachment:2d20ab47-4840-4725-bbdc-e383f9274e27.png)

# %% [markdown]
# ![image.png](attachment:7c461dd8-30fa-4062-b646-2ba6c7a3de4c.png)

# %% [markdown]
# ![image.png](attachment:e7d9f9f4-18ec-474b-9477-f6ba780bbea0.png)

# %% [markdown]
# ## What is a Data Pipeline?

# %% [markdown]
# https://www.youtube.com/watch?v=8-WH7CUdmzc

# %% [markdown]
# ![image.png](attachment:e775e847-4ad1-4cf7-9020-73a0926ec5d6.png)

# %% [markdown]
# https://www.xplenty.com/blog/etl-vs-elt/

# %% [markdown]
# https://docs.aws.amazon.com/AmazonS3/latest/dev/Welcome.html

# %% [markdown]
# https://docs.aws.amazon.com/AmazonS3/latest/userguide/Welcome.html

# %% [markdown]
# https://kafka.apache.org/intro

# %% [markdown]
# https://docs.aws.amazon.com/redshift/latest/mgmt/welcome.html

# %% [markdown]
# ## Lesson Review

# %% [markdown]
# https://www.youtube.com/watch?v=Yk4AZZSdbhw

# %% [markdown]
# ![image.png](attachment:262bc1f3-45ea-4ccf-81dc-50303602cab6.png)
