# %% [markdown]
# ##  Spark and Human Balance

# %% [markdown]
# ![image.png](attachment:2661eb13-8c69-4bb6-b4bd-6e2d8307b10a.png)

# %% [markdown]
# ## Environments

# %% [markdown]
# ![image.png](attachment:4adc55b4-5138-437c-9dc9-8a58eec7355a.png)

# %% [markdown]
# ## Project Data

# %% [markdown]
# ![image.png](attachment:39937ca6-0c83-4146-be78-1cfb289b7341.png)

# %% [markdown]
# https://github.com/udacity/nd027-Data-Engineering-Data-Lakes-AWS-Exercises/tree/main/project/starter

# %% [markdown]
# https://github.com/udacity/nd027-Data-Engineering-Data-Lakes-AWS-Exercises/tree/main

# %% [markdown]
# https://github.com/udacity/nd027-Data-Engineering-Data-Lakes-AWS-Exercises/tree/main/project/starter/customer/landing

# %% [markdown]
# https://github.com/udacity/nd027-Data-Engineering-Data-Lakes-AWS-Exercises/tree/main/project/starter/step_trainer/landing

# %% [markdown]
# https://github.com/udacity/nd027-Data-Engineering-Data-Lakes-AWS-Exercises/tree/main/project/starter/accelerometer/landing

# %% [markdown]
# https://github.com/udacity/nd027-Data-Engineering-Data-Lakes-AWS-Exercises/blob/main/project/README.md

# %% [markdown]
# ## Project Instructions

# %% [markdown]
# ![image.png](attachment:2f0d847e-f0ef-44fa-a996-cd7ba61158b8.png)

# %% [markdown]
# ## Troubleshooting

# %% [markdown]
# ![image.png](attachment:7ba58565-0b54-4e15-9ccb-fd9b689cf93a.png)

# %% [markdown]
# ![image.png](attachment:2180ae0d-270a-4abf-bccf-791f7ad132aa.png)
