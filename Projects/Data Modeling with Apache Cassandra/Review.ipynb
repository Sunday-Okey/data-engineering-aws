# %% [markdown]
# ![image.png](attachment:3b8d1a23-6886-43f4-be56-7db2f1b54cb4.png)

# %% [markdown]
# https://www.geeksforgeeks.org/system-design-when-to-and-when-not-to-use-cassandra/

# %% [markdown]
# ![image.png](attachment:ab8ee2a0-a52a-41b1-b363-b00ddce8bcc9.png)

# %% [markdown]
# ![image.png](attachment:79c9eeef-9d52-44f9-a622-3ed5de1642fd.png)

# %% [markdown]
# ![image.png](attachment:3ae6a457-8bff-4eb7-a9fb-f7d2ea6482f5.png)

# %% [markdown]
# ![image.png](attachment:fc1dd15d-bda7-4a57-931c-382f25f62cf0.png)

# %% [markdown]
# Student should use table names that reflect the query and the result it will generate. Table names should include alphanumeric characters and underscores, and table names must start with a letter.

# %% [markdown]
# https://www.tutorialspoint.com/database-table-and-column-naming-conventions

# %% [markdown]
# ![image.png](attachment:8e5363c8-b7c0-43db-8937-12bc6c52b56b.png)

# %% [markdown]
# https://docs.datastax.com/en/dse/5.1/cql/cql/cql_using/whereClustering.html

# %% [markdown]
# ![image.png](attachment:f5dae7de-da77-4f0e-b7df-b7ff63603ef4.png)

# %% [markdown]
# https://www.baeldung.com/cassandra-keys

# %% [markdown]
# https://www.datastax.com/blog/allow-filtering-explained

# %% [markdown]
# ![image.png](attachment:2d30b208-1d8c-401a-8517-ebcade2e5ec9.png)

# %% [markdown]
# https://towardsdatascience.com/enrich-your-jupyter-notebook-with-these-tips-55c8ead25255

# %% [markdown]
# ![image.png](attachment:a3461a7a-d276-4076-8172-e98e9beba687.png)

# %% [markdown]
# ![image.png](attachment:be335510-6479-44e8-a059-5b32116e838c.png)
