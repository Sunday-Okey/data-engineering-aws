# %% [markdown]
# ## Introduction

# %% [markdown]
# ![image.png](attachment:e9d71310-fd7b-4ac8-9d52-e1ffc5ee641c.png)

# %% [markdown]
# ## Project Details

# %% [markdown]
# ![image.png](attachment:0646bc03-0501-4277-89ea-e2c9a13ff6dc.png)

# %% [markdown]
# ![image.png](attachment:0026174c-19fe-4430-b222-54dbcf58f47c.png)

# %%
import pandas as pd

# %%
df = pd.read_csv('event_datafile_new.csv')

# %%
df.head()
# Out:
#               artist firstName gender  itemInSession lastName     length  \
# 0  Sydney Youngblood     Jacob      M             53    Klein  238.07955
# 1         Gang Starr     Layla      F             88  Griffin  151.92771
# 2              3OH!3     Layla      F             89  Griffin  192.52200
# 3        RÃÂ¶yksopp     Jacob      M             54    Klein  369.81506
# 4         Kajagoogoo     Layla      F             90  Griffin  223.55546
#
#   level                             location  sessionId  \
# 0  paid  Tampa-St. Petersburg-Clearwater, FL        954
# 1  paid         Lake Havasu City-Kingman, AZ        984
# 2  paid         Lake Havasu City-Kingman, AZ        984
# 3  paid  Tampa-St. Petersburg-Clearwater, FL        954
# 4  paid         Lake Havasu City-Kingman, AZ        984
#
#                                           song  userId
# 0                            Ain't No Sunshine      73
# 1                   My Advice 2 You (Explicit)      24
# ...

# %%
df[(df['sessionId']==182) & (df['userId'] == 10)]
# Out:
#                  artist firstName gender  itemInSession lastName     length  \
# 1867   Down To The Bone    Sylvie      F              0     Cruz  333.76608
# 1868       Three Drives    Sylvie      F              1     Cruz  411.63710
# 1869  Sebastien Tellier    Sylvie      F              2     Cruz  377.73016
# 1870      Lonnie Gordon    Sylvie      F              3     Cruz  181.21098
#
#      level                                      location  sessionId  \
# 1867  free  Washington-Arlington-Alexandria, DC-VA-MD-WV        182
# 1868  free  Washington-Arlington-Alexandria, DC-VA-MD-WV        182
# 1869  free  Washington-Arlington-Alexandria, DC-VA-MD-WV        182
# 1870  free  Washington-Arlington-Alexandria, DC-VA-MD-WV        182
#
#                                                    song  userId
# 1867                                 Keep On Keepin' On      10
# 1868                                        Greece 2000      10
# ...

# %%
df[df['song'] == 'All Hands Against His Own']
# Out:
#               artist   firstName gender  itemInSession lastName     length  \
# 3511  The Black Keys        Sara      F             31  Johnson  196.91057
# 5402  The Black Keys       Tegan      F             25   Levine  196.91057
# 6067  The Black Keys  Jacqueline      F             50    Lynch  196.91057
#
#      level                           location  sessionId  \
# 3511  paid                  Winston-Salem, NC        152
# 5402  paid        Portland-South Portland, ME        611
# 6067  paid  Atlanta-Sandy Springs-Roswell, GA        559
#
#                            song  userId
# 3511  All Hands Against His Own      95
# 5402  All Hands Against His Own      80
# 6067  All Hands Against His Own      29
