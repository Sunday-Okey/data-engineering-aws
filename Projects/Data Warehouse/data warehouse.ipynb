# %% [markdown]
# ## Project: Data Warehouse

# %% [markdown]
# Data Warehouse
#
# In this project, learners will act as a data engineer for a streaming music service. They are tasked with
# building an ELT pipeline that extracts data from S3, stages it in Redshift, and transforms it into a set of
# dimensional tables for an analytics team to find insights into what songs their users are listening to.

# %% [markdown]
# ### Introduction
#
# A music streaming startup, Sparkify, has grown their user base and song database and want to move their processes and data onto the cloud. Their data resides in S3, in a directory of JSON logs on user activity on the app, as well as a directory with JSON metadata on the songs in their app.
#
# As their data engineer, you are tasked with building an ETL pipeline that extracts their data from S3, stages them in Redshift, and transforms data into a set of dimensional tables for their analytics team to continue finding insights into what songs their users are listening to.

# %% [markdown]
# ![image.png](attachment:9969b7f7-3f30-4e3f-9dc8-343cb9a6eef8.png)

# %% [markdown]
# System Architecture for AWS S3 to Redshift ETL

# %% [markdown]
# ![image.png](attachment:39c285f3-563e-48cd-a316-6d6d8f2d6342.png)

# %% [markdown]
# ## Course - AWS Sign In and Costs

# %% [markdown]
# ![image.png](attachment:098601dd-96a4-4e71-bc23-cd9881ca5ef7.png)

# %% [markdown]
# ## Project Datasets

# %% [markdown]
# ![image.png](attachment:9414ca34-3928-4535-a44f-cf1692f85b5e.png)

# %% [markdown]
# ## Project Instructions

# %% [markdown]
# ![image.png](attachment:6db60fbb-0ceb-4e6c-acbd-b6c1df10c49a.png)

# %% [markdown]
# https://www.markdownguide.org/basic-syntax/

# %% [markdown]
# https://docs.aws.amazon.com/redshift/latest/dg/r_CREATE_TABLE_NEW.html
