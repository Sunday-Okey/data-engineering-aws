# %% [markdown]
# ## Introduction to Cloud Data Warehouses

# %% [markdown]
# Building a data warehouse in a cloud environment has it's advantages. The power of the cloud comes from connecting compute and storage resources from many physical servers together in order to provide as much or as little resources you need to move, transform, and store data.

# %% [markdown]
# https://www.youtube.com/watch?v=3a8w375LG-g

# %% [markdown]
# ![image.png](attachment:59b643d5-7692-4ea1-8786-eff9e0160ded.png)

# %% [markdown]
# ## Lesson Outline
# In this lesson, you'll learn about the technologies involved in building data warehouses in the cloud.

# %% [markdown]
# https://www.youtube.com/watch?v=8j00CB-ibS8

# %% [markdown]
# ![image.png](attachment:0963fa9a-2f28-4468-a9f3-b7945a0090ed.png)

# %% [markdown]
# ## Expert Perspective: Cloud Data Warehouses

# %% [markdown]
# https://www.youtube.com/watch?v=RHqEhShoyqU

# %% [markdown]
# ![image.png](attachment:82556ea6-6b82-4b22-89e3-6f88a52f6923.png)

# %% [markdown]
# ## From ETL to ELT

# %% [markdown]
# ## ELT in Cloud Environments
# Massive parallel processing and distributed file storage capabilities of cloud computing have led to new extract, transform, and load design patterns. Traditional ETL models have worked for decades but the introduction of massive scalability through cloud data warehousing has allowed us to flip the Transform and Load steps.

# %% [markdown]
# ![image.png](attachment:594c0dde-ab4f-4eb5-b5b4-4402822a6db0.png)

# %% [markdown]
# https://aws.amazon.com/ko/compare/the-difference-between-etl-and-elt/

# %% [markdown]
# https://docs.microsoft.com/en-us/azure/synapse-analytics/sql-data-warehouse/design-elt-data-loading

# %% [markdown]
# ![image.png](attachment:70ad714e-ae6c-45c5-9d63-d9e5baf4879e.png)

# %% [markdown]
# ![image.png](attachment:97c1e203-5d04-4094-b36d-ff551df569b8.png)

# %% [markdown]
# ![image.png](attachment:6fc731f5-0849-4474-ba54-0edc1c2ca1f1.png)

# %% [markdown]
# ## Solution: ELT

# %% [markdown]
# ![image.png](attachment:a8561575-d630-412d-a66d-d4e4e6a6a5a4.png)

# %% [markdown]
# ## Cloud Managed SQL Storage

# %% [markdown]
# https://www.youtube.com/watch?v=coEwgkP5-RY

# %% [markdown]
# ![image.png](attachment:3ec689b1-b50a-4cc2-9ed7-7cadedadff96.png)

# %% [markdown]
# ## Cloud Managed NoSQL Storage

# %% [markdown]
# https://www.youtube.com/watch?v=rt8TNBbEZ_8

# %% [markdown]
# ![image.png](attachment:d75e1b0c-1247-4935-ac1f-e4882da61fcb.png)

# %% [markdown]
# ## Cloud Data Storage Quizzes

# %% [markdown]
# ![image.png](attachment:348d2b7a-0d2c-4580-947e-8ce2f5bed0d9.png)

# %% [markdown]
# ## Cloud ETL Pipeline Services

# %% [markdown]
# https://www.youtube.com/watch?v=KNuBVDEu5IM

# %% [markdown]
# ![image.png](attachment:29dad117-f571-4aa1-b277-d1661fd1c0a8.png)

# %% [markdown]
# ## Cloud Pipeline Services Quizzes

# %% [markdown]
# ![image.png](attachment:a6296627-018c-4b6b-977c-0ffee69d2d84.png)

# %% [markdown]
# ## Cloud Data Warehouse Solutions

# %% [markdown]
# https://www.youtube.com/watch?v=X4DUrGDSd-0

# %% [markdown]
# The last piece of the puzzle for Cloud Data Warehousing is the data warehouse itself. Modern cloud data warehouse solutions seamlessly combine elements from Cloud Storage and Cloud Pipelines with powerful analytics capabilities. Each of the three major cloud providers has its own flavor of Cloud Data Warehouse that works seamlessly with its other cloud data engineering offerings.
#
# - Azure Synapse
# - Amazon Redshift
# - GCP Big Query

# %% [markdown]
# ## Cloud Data Warehouse Solutions Quizzes

# %% [markdown]
# ![image.png](attachment:aa83fcfa-459e-49e0-a345-b41cdc1e96fc.png)

# %% [markdown]
# ## Lesson Review

# %% [markdown]
# https://www.youtube.com/watch?v=PnbF5KnCTy0

# %% [markdown]
# ![image.png](attachment:0e6a9d83-7b95-40e4-947a-15edb8b6cec8.png)
