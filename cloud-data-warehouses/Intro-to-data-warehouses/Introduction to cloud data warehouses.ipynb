# %% [markdown]
# ## Introduction to cloud data warehouses

# %% [markdown]
# ![image.png](attachment:9bcf4d53-f78c-4cfd-b158-4ae0bc00cecc.png)

# %% [markdown]
# https://www.youtube.com/watch?v=9KE0DaENiBk

# %% [markdown]
# ![image.png](attachment:9a2724de-6119-421e-b0fc-db426370be85.png)

# %% [markdown]
# ## Prerequisites

# %% [markdown]
# ![image.png](attachment:8b987517-c978-400b-92bf-2b74fc45e973.png)

# %% [markdown]
# https://www.udacity.com/course/database-systems-concepts-design--ud150

# %% [markdown]
# https://www.udacity.com/course/intro-to-relational-databases--ud197

# %% [markdown]
# https://www.udacity.com/blog/2021/04/an-introduction-to-relational-databases-and-sql.html

# %% [markdown]
# https://www.udacity.com/course/introduction-to-python--ud1110

# %% [markdown]
# https://www.udacity.com/course/intro-to-data-analysis--ud170

# %% [markdown]
# https://www.udacity.com/course/intro-to-cloud-computing--ud080

# %% [markdown]
# https://docs.aws.amazon.com/index.html

# %% [markdown]
# https://docs.aws.amazon.com/index.html#tutorials

# %% [markdown]
# ![image.png](attachment:b543eed8-5eaf-40a6-8023-c13e102b2c00.png)

# %% [markdown]
# ## Tools and Environment

# %% [markdown]
# ![image.png](attachment:3fbc034c-5de8-4c9d-95ff-db334644d79c.png)

# %% [markdown]
# https://www.python.org/downloads/

# %% [markdown]
# https://www.postgresql.org/

# %% [markdown]
# https://wiki.postgresql.org/wiki/Sample_Databases

# %% [markdown]
# https://jupyter.org/

# %% [markdown]
# https://aws.amazon.com/cli/

# %% [markdown]
# https://code.visualstudio.com/

# %% [markdown]
# ## Project Preview

# %% [markdown]
# Project Preview
#
# At the end of the course, you'll use all of the skills you learned to build a data warehouse solution on the AWS cloud. You'll extract data from AWS S3, transform it using SQL and Python, and load it into an AWS Redshift data warehouse.

# %% [markdown]
# ![image.png](attachment:d17e7662-0136-4094-bdc1-1ac4f1ad0ec7.png)

# %% [markdown]
# ## Project Description
# In this project, you'll act as a data engineer for a music streaming startup called Sparkify.
#
# Sparkify has grown its user base and song database and wants to move its processes, data, and data analytics applications onto the cloud.
#
# Their data resides in S3, in a directory of JSON logs on user activity on the app, and a directory with JSON metadata for the songs in their app. As their data engineer, you will be tasked with building an ETL pipeline that extracts their data from S3, stages them in Redshift, and transforms data into a set of dimensional tables for their analytics team to continue finding insights into what songs their users are listening to.

# %% [markdown]
# ## Course Overview

# %% [markdown]
# ![image.png](attachment:17886724-4ed5-4032-8959-2af78a42c74e.png)
