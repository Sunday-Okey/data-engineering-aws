# %% [markdown]
# ## Lesson Introduction: Implementing Data Warehouses on AWS

# %% [markdown]
# https://www.youtube.com/watch?v=SDWQQ2r9zao

# %% [markdown]
# ![image.png](attachment:65ec126f-6f0d-4326-801d-e75af4d30dcc.png)

# %% [markdown]
# https://www.youtube.com/watch?v=nQROE5NXnO4

# %% [markdown]
# ## Amazon Redshift

# %% [markdown]
# https://www.youtube.com/watch?v=svUukvPMcGE

# %% [markdown]
# ![image.png](attachment:5ae1f69b-15a7-4266-9502-7f1913e7c36e.png)

# %% [markdown]
# ## Amazon Redshift Architecture

# %% [markdown]
# ![image.png](attachment:55f6e640-bfd2-4562-ac6e-5e620359e1a4.png)

# %% [markdown]
# ## Ingesting Data at Scale

# %% [markdown]
# ## Redshift Solution Architecture and ETL

# %% [markdown]
# https://www.youtube.com/watch?v=9OdB4m0y-K0

# %% [markdown]
# ![image.png](attachment:b64dd2bd-c12b-4d81-8bca-d6fd1f3234ec.png)

# %% [markdown]
# ## ETL with Redshift Quiz

# %% [markdown]
# ![image.png](attachment:b0a7818d-cb7d-4f34-b05e-72577d26d5a2.png)

# %% [markdown]
# ## Exercise: ETL in Redshift

# %% [markdown]
# https://www.youtube.com/watch?v=ZeFEotdv6Ig

# %% [markdown]
# ## Optimizing Table Design with Distribution Styles

# %% [markdown]
# https://www.youtube.com/watch?v=Yu6RcUbIbM0

# %% [markdown]
# ![image.png](attachment:790287a7-c922-4614-8a84-cd44ba76826e.png)

# %% [markdown]
# ## Distribution Styles Quiz

# %% [markdown]
# ![image.png](attachment:e8c38064-4e6a-4646-a1e8-724846f27751.png)

# %% [markdown]
# ## Solution: Distribution Styles

# %% [markdown]
# https://www.youtube.com/watch?v=6fXns_Txwqc

# %% [markdown]
# ![image.png](attachment:e57850d0-1e7e-479e-973a-46497a41ec1f.png)

# %% [markdown]
# ## Lesson Review

# %% [markdown]
# https://www.youtube.com/watch?v=b_ylcNiiSpY

# %% [markdown]
# ![image.png](attachment:dcdbefad-7bf8-48eb-8198-2ef4fb12c26e.png)
