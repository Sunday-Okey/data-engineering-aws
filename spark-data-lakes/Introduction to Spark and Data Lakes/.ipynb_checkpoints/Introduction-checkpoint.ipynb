# %% [markdown]
# ## Introduction to Spark and Data Lakes

# %% [markdown]
# ### Course Introduction

# %% [markdown]
# ![image.png](attachment:2dd746a2-e37e-40be-be98-f87e096781ec.png)

# %% [markdown]
# https://www.youtube.com/watch?v=u3s8E3R_UHc

# %% [markdown]
# ## Prerequisites

# %% [markdown]
# ![image.png](attachment:3e0bad49-02d1-402f-833f-29d3b7937311.png)

# %% [markdown]
# https://www.udacity.com/course/database-systems-concepts-design--ud150

# %% [markdown]
# https://www.udacity.com/course/intro-to-relational-databases--ud197

# %% [markdown]
# https://www.udacity.com/blog/2021/04/an-introduction-to-relational-databases-and-sql.html

# %% [markdown]
# https://www.udacity.com/course/introduction-to-python--ud1110

# %% [markdown]
# https://www.udacity.com/course/intro-to-data-analysis--ud170

# %% [markdown]
# https://www.udacity.com/course/intro-to-cloud-computing--ud080

# %% [markdown]
# https://docs.aws.amazon.com/index.html

# %% [markdown]
# https://docs.aws.amazon.com/index.html#tutorials

# %% [markdown]
# ## Course Outline

# %% [markdown]
# In this course, you'll be working in the modern big data ecosystem with Apache Spark, Python, and Amazon Web Services.

# %% [markdown]
# https://www.youtube.com/watch?v=cLZprHVGH88

# %% [markdown]
# ![image.png](attachment:bafcbd9b-ad4a-42d4-8d55-e4893c3882ee.png)

# %% [markdown]
# ## Tools and Environment

# %% [markdown]
# ![image.png](attachment:402e88ca-104e-4c5e-baba-1a4ee3497c34.png)

# %% [markdown]
# https://www.python.org/downloads/

# %% [markdown]
# https://spark.apache.org/docs/latest/api/python/getting_started/install.html

# %% [markdown]
# https://spark.apache.org/

# %% [markdown]
# https://code.visualstudio.com/

# %% [markdown]
# https://aws.amazon.com/cli/

# %% [markdown]
# ## Exercise Github Repository
# You can find the starter code and solutions to the practice scripts and exercises in Github here(opens in a new tab), as well as downloading them from the workspaces using the right-click menu and choosing Download

# %% [markdown]
# https://github.com/udacity/nd027-Data-Engineering-Data-Lakes-AWS-Exercises

# %% [markdown]
# ## Project Preview

# %% [markdown]
# https://www.youtube.com/watch?v=__dI0Ocjd1Q

# %% [markdown]
# ![image.png](attachment:cd6aa3dc-d04d-4a7b-b32a-fb91daa7a96a.png)

# %% [markdown]
# ## Good Luck

# %% [markdown]
# https://www.youtube.com/watch?v=IPKZl45y_vs

# %% [markdown]
# Congratulations on taking the initiative to study Spark in AWS. I can promise you that the time you spend will be challenging but rewarding.

# %% [markdown]
# https://github.com/udacity/nd027-Data-Engineering-Data-Lakes-AWS-Exercises
